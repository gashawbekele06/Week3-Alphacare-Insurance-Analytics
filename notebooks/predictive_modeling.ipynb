# %% [markdown]
# ## Task 4: Predictive Modeling & Risk-Based Pricing

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", font_scale=1.2)
plt.rcParams["figure.figsize"] = (14, 8)

print("Setup complete – ready to run Task 4 modeling")
# Out:
# Setup complete – ready to run Task 4 modeling

# %%
# Run the complete Task 4 modeling pipeline
from src.predictive_modeling import PredictiveModeling

modeling = PredictiveModeling()
modeling.run()
# Out:
# INFO:src.data_loader:Delimiter found: '|'
# Loading and preparing data...
# INFO:src.data_loader:Loaded 1,000,098 rows
# Severity modeling on 2,788 claims
# Features used: 21
# TASK 4: PREDICTIVE MODELING & RISK-BASED PRICING
#
# ==========================================================================================
# CLAIM SEVERITY PREDICTION (TotalClaims | Claim > 0)
# ==========================================================================================
# Linear Regression  → RMSE: R  36,744 | R²: 0.160
# Random Forest      → RMSE: R  34,073 | R²: 0.278
