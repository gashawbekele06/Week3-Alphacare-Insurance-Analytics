# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from src.eda_analysis import ExploratoryDataAnalysis

ExploratoryDataAnalysis().run_complete_eda()
# Out:
# INFO:src.data_loader:Delimiter found: '|'
# Loading and preparing data...
# INFO:src.data_loader:Loaded 1,000,098 rows
# Data loaded and engineered successfully (zero warnings).
# ====================================================================================================
# TASK 1: EXPLORATORY DATA ANALYSIS – ALPHACARE INSURANCE
# ====================================================================================================
#
# 1. DATA STRUCTURE
#    Shape: 1,000,098 rows × 55 columns
#    Date Range: 2013-10-01 00:00:00 to 2015-08-01 00:00:00
#
# 2. DESCRIPTIVE STATISTICS
#                    mean         std      50%          max
# TotalPremium      61.91      230.28     2.18     65282.60
# TotalClaims       64.86     2384.07     0.00    393092.11
# SumInsured    604172.73  1508331.84  7500.00  12636200.00
#
#    OVERALL PORTFOLIO LOSS RATIO: 104.77%
#
# 3. MISSING VALUES (%)
# NumberOfVehiclesInFleet    100.0
# CrossBorder                 99.9
# ClaimSeverity               99.7
# CustomValueEstimate         78.0
# Converted                   64.2
# Rebuilt                     64.2
# WrittenOff                  64.2
# LossRatio                   38.2
# NewVehicle                  15.3
# Bank                        14.6
#
# 4. UNIVARIATE ANALYSIS
# 5. PREMIUM vs CLAIMS BY POSTAL CODE (Monthly)
# 6. GEOGRAPHIC TRENDS – Loss Ratio by Province
#    Loss Ratio by Province:
# Province
# Gauteng          122.20%
# KwaZulu-Natal    108.27%
# Western Cape     105.95%
# North West        79.04%
# Mpumalanga        72.09%
# Free State        68.08%
# Limpopo           66.12%
# Eastern Cape      63.38%
# Northern Cape     28.27%
# 7. OUTLIER DETECTION
# 8. THREE CREATIVE & ACTIONABLE INSIGHTS
# TASK 1 COMPLETED – ALL REQUIREMENTS MET – ZERO WARNINGS
# ====================================================================================================
